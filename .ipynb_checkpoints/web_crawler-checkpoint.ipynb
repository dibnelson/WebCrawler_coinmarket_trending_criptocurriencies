# %%
import requests
from requests.exceptions import HTTPError
from bs4  import BeautifulSoup
import re
import csv
import pandas as pd

# %%
URL = 'https://coinmarketcap.com/pt-br/trending-cryptocurrencies/'
content = None
def webXtractor(url : str):
    try:
        out = requests.get(url)
        out.raise_for_status()
    except HTTPError as exc:
        print(exc)
    else:
        content = out.text
        return content

# %%
content = webXtractor(URL)

# %%
with open(file='cripto.html',mode='w',encoding='utf8')as fl:
    fl.write(content)

# %%
page = BeautifulSoup(open('cripto.html',mode='r',encoding='utf8'),'html.parser')
table = page.find('tbody')
extractor = []

for line in table.find_all('tr'):
    text_column = list()
    for column in line.find_all('td'):
        text = column.get_text().strip().split('\n')
        text_column += text
    extractor.append(text_column)

# %%
with open(file='./cripto.csv',mode='w',encoding='utf8') as fl:
    write = csv.writer(fl,delimiter=';')
    write.writerow(['#','name','price','24h','7d','30d','market'])
    for line in extractor:
        write.writerow([str(line[1]),str(line[2]),str(line[3]),str(line[4]),str(line[5]),str(line[6]),str(line[7])])

# %%
cripto_df = pd.read_csv('./cripto.csv',sep=';')

# %%
def cleaner (DataFrame,column):
    for col in column:
        DataFrame[col] = DataFrame[col].str.replace(r'\d+',' - ',regex=True)

# %%
cleaner(cripto_df,['name'])

# %%
cripto_df
# Out:
#      #                    name         price     24h       7d      30d  \
# 0    1           Bitcoin - BTC  R$104,486.75   8.24%    3.76%   17.30%
# 1    2             Reef - REEF     R$0.02954  14.55%   60.32%   24.81%
# 2    3        Shiba Inu - SHIB    R$0.000063   3.81%    0.77%   26.66%
# 3    4      PancakeSwap - CAKE       R$21.54   4.40%    3.22%    3.20%
# 4    5          Ethereum - ETH    R$8,267.46   5.42%    1.57%   18.19%
# 5    6  Ethereum Classic - ETC      R$184.80   5.35%    2.78%   14.16%
# 6    7     Loom Network - LOOM      R$0.4137  15.30%   78.11%   46.86%
# 7    8         Ravencoin - RVN      R$0.3213  12.15%   66.22%   67.18%
# 8    9           Cosmos - ATOM       R$73.96   6.18%   16.54%   22.14%
# 9   10            Solana - SOL      R$175.71   8.06%    6.25%   25.39%
# 10  11           Cardano - ADA        R$2.43   5.93%    1.26%   17.72%
# 11  12               BNB - BNB    R$1,445.24   3.16%    2.77%   12.72%
# 12  13           Tribe - TRIBE        R$1.19   1.46%   19.54%   52.33%
# 13  14         Polygon - MATIC        R$4.44   6.41%    1.24%   14.92%
# 14  15             WETH - WETH    R$8,256.83   5.57%    1.61%   18.19%
# 15  16  TerraClassicUSD - USTC      R$0.2354   4.14%    4.41%   58.64%
# 16  17          Litecoin - LTC      R$306.87   1.70%    5.01%    6.90%
# 17  18     Decentraland - MANA        R$3.84   5.28%    2.19%   30.81%
# 18  19           Stellar - XLM      R$0.5477   5.83%    3.06%   15.94%
# 19  20             IOST - IOST     R$0.06651   2.61%    2.14%   18.91%
# 20  21          Bluzelle - BLZ      R$0.4279   5.30%    3.35%   16.81%
# 21  22             Golem - GLM        R$1.81  13.21%   51.92%   21.06%
# 22  23            Terra - LUNA       R$21.58   1.88%  120.84%  104.31%
# 23  24     SKALE Network - SKL      R$0.2322   7.54%    4.18%   33.31%
# 24  25      KuCoin Token - KCS       R$48.03   3.47%    0.44%   13.20%
# 25  26    Terra Classic - LUNC    R$0.001823   7.99%   13.44%  249.77%
# 26  27              JUST - JST      R$0.1371   4.04%    1.21%   22.91%
# 27  28       OMG Network - OMG        R$9.36   6.76%    3.45%   22.57%
# 28  29         Moonbeam - GLMR        R$2.71   6.48%    5.66%   25.54%
# 29  30            IOTA - MIOTA        R$1.41   5.10%    1.34%   21.89%
#
#                  market
# 0   R$2,000,913,513,128
# 1         R$591,019,220
# 2      R$34,592,471,939
# 3       R$3,010,076,905
# 4   R$1,011,573,107,511
# 5      R$25,290,685,019
# 6         R$537,792,254
# 7       R$3,365,354,433
# 8      R$21,180,574,877
# 9      R$62,097,464,316
# 10     R$83,214,732,574
# 11    R$233,170,486,515
# 12        R$539,642,086
# 13     R$38,772,358,799
# 14                   --
# 15      R$2,310,224,561
# 16     R$21,837,621,335
# 17      R$7,125,181,724
# 18     R$13,886,349,882
# 19      R$1,236,337,040
# 20        R$145,902,410
# 21      R$1,809,553,022
# 22      R$2,751,301,256
# 23        R$860,417,506
# 24      R$4,725,200,460
# 25     R$11,215,541,938
# 26      R$1,220,588,322
# 27      R$1,313,243,120
# 28      R$1,053,206,542
# 29      R$3,917,713,264
